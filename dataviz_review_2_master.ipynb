# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/dataviz/players_22.csv')
df.head()
# Out:
# <ipython-input-5-3cee5cd901bf>:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/dataviz/players_22.csv')
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# ...

# %%
plt.scatter(df['overall'], df['potential'])

# %%
df.corr()
# Out:
#                              sofifa_id   overall  potential  value_eur  \
# sofifa_id                     1.000000 -0.491523   0.037576  -0.128102
# overall                      -0.491523  1.000000   0.644275   0.554684
# potential                     0.037576  0.644275   1.000000   0.527738
# value_eur                    -0.128102  0.554684   0.527738   1.000000
# wage_eur                     -0.253044  0.601764   0.497611   0.823527
# age                          -0.781023  0.459451  -0.264142   0.042886
# height_cm                    -0.100362  0.042787   0.004403   0.010291
# weight_kg                    -0.207461  0.150324  -0.016912   0.035188
# club_team_id                  0.110305 -0.226640  -0.330928  -0.191468
# league_level                 -0.036769 -0.179032  -0.153075  -0.117917
# club_jersey_number            0.183841 -0.186166   0.009784  -0.067670
# club_contract_valid_until     0.128058  0.184987   0.345188   0.217051
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# We see, surprisingly, that among all of a player's attributes, the `movement_reactions` attribute is the one that correlates the most with the overall rating of the player.

# %%
sns.regplot(x=df['movement_reactions'], y=df['overall'], scatter_kws={'color': 'lightblue'})
# Out:
# <Axes: xlabel='movement_reactions', ylabel='overall'>

# %% [markdown]
# With this piece of information, we will try to build a linear regression model for this

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df['movement_reactions'], df['overall'], test_size=0.33)

# %%
model = LinearRegression()
model.fit(X_train.to_numpy().reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test.to_numpy().reshape(-1, 1), y_test)
# Out:
# 0.7623894502169068

# %%
from sklearn.svm import SVR

# %%
model = SVR()
model.fit(X_train.to_numpy().reshape(-1, 1), y_train)
model.score(X_test.to_numpy().reshape(-1, 1), y_test)
# Out:
# 0.774280872742461

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
model = Lasso()
model.fit(X_train.to_numpy().reshape(-1, 1), y_train)
model.score(X_test.to_numpy().reshape(-1, 1), y_test)
# Out:
# 0.7623267296258371

# %%
model = Ridge()
model.fit(X_train.to_numpy().reshape(-1, 1), y_train)
model.score(X_test.to_numpy().reshape(-1, 1), y_test)
# Out:
# 0.7623894609302242

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
model = DecisionTreeRegressor()
model.fit(X_train.to_numpy().reshape(-1, 1), y_train)
model.score(X_test.to_numpy().reshape(-1, 1), y_test)
# Out:
# 0.773841111349304

# %%
_ = plot_tree(model)

# %%
df['player_positions_list'] = df.player_positions.str.split(',')
df['player_positions_list']
# Out:
# 0        [RW,  ST,  CF]
# 1                  [ST]
# 2             [ST,  LW]
# 3            [LW,  CAM]
# 4            [CM,  CAM]
#               ...
# 19234             [CDM]
# 19235              [CM]
# 19236              [CM]
# 19237              [ST]
# 19238             [CAM]
# Name: player_positions_list, Length: 19239, dtype: object

# %%
df_exploded = df.explode('player_positions_list')
df_exploded.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
#
#    overall  potential    value_eur  wage_eur  age  ...    cb   rcb    rb  \
# ...

# %%
attributes = df_exploded.columns[37:77]

# %%
attributes
# Out:
# Index(['pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes'],
#       dtype='object')

# %%
mask = df_exploded[attributes].isna().any(axis=1)

# %%
X = df_exploded[attributes][~mask]
y = df_exploded['player_positions_list'][~mask]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
_ = plot_tree(model)

# %%
mentalities = list(filter(lambda x: x.startswith('mentality'), attributes))

# %%
fig, ax = plt.subplots(nrows=3, ncols=2)
i = 0
for row in ax:
  for col in row:
    col.plot(df[mentalities[i]], df.overall)
    i += 1

# %%
sns.heatmap(df[mentalities + ['overall']].corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans

# %%
labels = KMeans(random_state=1).fit_predict(df_exploded[attributes][~mask])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
print(set(labels))
print(len(set(labels)))
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}
# 8

# %%
filtered0 = df_exploded[attributes][~mask][labels == 1]
filtered1 = df_exploded[attributes][~mask][labels == 2]
plt.scatter(filtered0.loc[:,"pace"], filtered0.loc[:, "shooting"], color='#5e81ac')
plt.scatter(filtered1.loc[:,"pace"], filtered1.loc[:, "shooting"], color='#b48ead')
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
model = Sequential()
model.add(LSTM(units=128, input_shape=(X_train.shape[1], 1)))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=len(set(y)), activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train.reshape(X_train.shape[0], X_train.shape[1], 1), y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 597/597 [==============================] - 43s 71ms/step - loss: 2.3277 - accuracy: 0.2931 - val_loss: 2.2690 - val_accuracy: 0.3126
# Epoch 2/10
# 597/597 [==============================] - 47s 78ms/step - loss: 2.2874 - accuracy: 0.3002 - val_loss: 2.2506 - val_accuracy: 0.3111
# Epoch 3/10
# 597/597 [==============================] - 34s 56ms/step - loss: 2.2528 - accuracy: 0.3085 - val_loss: 2.1916 - val_accuracy: 0.3258
# Epoch 4/10
# 597/597 [==============================] - 34s 57ms/step - loss: 2.2220 - accuracy: 0.3146 - val_loss: 2.1720 - val_accuracy: 0.3241
# Epoch 5/10
# 597/597 [==============================] - 33s 56ms/step - loss: 2.1968 - accuracy: 0.3195 - val_loss: 2.1586 - val_accuracy: 0.3371
# Epoch 6/10
# 597/597 [==============================] - 36s 61ms/step - loss: 2.1748 - accuracy: 0.3283 - val_loss: 2.1168 - val_accuracy: 0.3461
# Epoch 7/10
# ...

# %%
accuracy = model.evaluate(X_test.reshape(X_test.shape[0], X_test.shape[1], 1), y_test)
print('Test accuracy:', accuracy[1])
# Out:
# 187/187 [==============================] - 6s 34ms/step - loss: 2.1228 - accuracy: 0.3369
# Test accuracy: 0.3369109630584717

# %% [markdown]
# Seeing the woeful accuracy, we decided to settle on the right number of epochs.
#
# For this, we modeled the epochs-accuracy relationship. We made an educated guess of a logarithmic function.
#
# The working can be viewed [here](https://docs.google.com/spreadsheets/d/1Okvz8_2RQX2ewyXWu-1BnPQwYicY3MeP6gDql85G8hA/edit?usp=sharing).
#
# It was found that around 2000 epochs allows it to converge to a decent accuracy. This requires a lot of compute power which we don't have, but just putting it out there.
